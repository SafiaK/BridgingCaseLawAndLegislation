# %%
import sys
import os

# Add the src folder to Python path
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

# Load environment variables from src/.env
from dotenv import load_dotenv
load_dotenv(os.path.join(os.path.dirname(os.getcwd()), 'src', '.env'))
# Out:
# True

# %%
import make_batch_jsonl_law_application

# %%
import pandas as pd
df_total = pd.read_csv('../data/final_test/combined_sampled_caselaws.csv')
df_sample = df_total.sample(10)

prompt_file = '../data/final_test/prompt.txt'

output_path = '../data/final_test/combined_Qwen.jsonl'

examples_file = '../data/final_test/examples.json'

jsonl_files =make_batch_jsonl_law_application.create_batch_jsonl(
    model_name='qwen-qwq-32b',
    prompt_file=prompt_file,
    examples_file=examples_file,
    df=df_total,
    output_path=output_path
)
# Out:
# Warning: Could not detect provider for model 'qwen-qwq-32b'. Defaulting to OpenAI limits.
# Detected provider: OpenAI
# Limits: 50,000 requests, 100MB per file
# Building JSONL requests...
#
# Analysis:
#   Total requests: 24,578
#   Estimated size: 250.8 MB
#   Splits needed: 3 (due to file size (250.8MB > 100MB))
#
# 📂 Creating 3 files...
#    ✅ ../data/final_test/combined_Qwen_part_01.jsonl
#       Size: 82.2 MB (limit: 100 MB)
#       Requests: 8,193 (limit: 50,000)
#    ✅ ../data/final_test/combined_Qwen_part_02.jsonl
#       Size: 81.9 MB (limit: 100 MB)
#       Requests: 8,193 (limit: 50,000)
#    ✅ ../data/final_test/combined_Qwen_part_03.jsonl
#       Size: 82.1 MB (limit: 100 MB)
#       Requests: 8,192 (limit: 50,000)
#
# 📋 Summary:
#    Provider: OpenAI
#    Model: qwen-qwq-32b
#    Files created: 3
#    Total requests: 24,578
#    Total size: 246.3 MB
#
# 📁 Output files:
#    1. ../data/final_test/combined_Qwen_part_01.jsonl
#    2. ../data/final_test/combined_Qwen_part_02.jsonl
#    3. ../data/final_test/combined_Qwen_part_03.jsonl

# %%
import os
from groq import Groq

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

file_path = "../data/final_test/combined_Qwen_part_01.jsonl"
response = client.files.create(file=open(file_path, "rb"), purpose="batch")

print(response)
# Out:
# FileCreateResponse(id='file_01jxf3fxefewb85f2v1qvttwde', bytes=86220111, created_at=1749632416, filename='combined_Qwen_part_01.jsonl', object='file', purpose='batch', size=0, md5='tbADMxMt20H8imZsO8jdQw==')

# %%
import os
from groq import Groq

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

response = client.batches.create(
    completion_window="24h",
    endpoint="/v1/chat/completions",
    input_file_id="file_01jxf3fxefewb85f2v1qvttwde",
)
print(response.to_json())
# Out:
# {
#   "id": "batch_01jxf3gv1nekf9v07wqea1y6nc",
#   "completion_window": "24h",
#   "created_at": 1749632445,
#   "endpoint": "/v1/chat/completions",
#   "input_file_id": "file_01jxf3fxefewb85f2v1qvttwde",
#   "object": "batch",
#   "status": "validating",
#   "cancelled_at": null,
#   "cancelling_at": null,
#   "completed_at": null,
#   "error_file_id": null,
#   "errors": null,
#   "expired_at": null,
#   "expires_at": 1749718845,
#   "failed_at": null,
#   "finalizing_at": null,
#   "in_progress_at": null,
#   "metadata": null,
#   "output_file_id": null,
#   "request_counts": {
#     "completed": 0,
#     "failed": 0,
#     "total": 0
#   }
# }

# %%
response = client.batches.retrieve("batch_01jxf3gv1nekf9v07wqea1y6nc")

print(response.to_json())
# Out:
# {
#   "id": "batch_01jxf3gv1nekf9v07wqea1y6nc",
#   "completion_window": "24h",
#   "created_at": 1749632445,
#   "endpoint": "/v1/chat/completions",
#   "input_file_id": "file_01jxf3fxefewb85f2v1qvttwde",
#   "object": "batch",
#   "status": "failed",
#   "cancelled_at": null,
#   "cancelling_at": null,
#   "completed_at": null,
#   "error_file_id": null,
#   "errors": {
#     "data": [
#       {
#         "code": "invalid_request_body",
#         "line": 1,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 2,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 3,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 4,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 5,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 6,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 7,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 9,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 10,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 11,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 12,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 13,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 14,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 15,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 16,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 17,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 18,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 19,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 20,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 21,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 22,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 23,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 24,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 25,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 26,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 27,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 28,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 29,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 30,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 31,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 32,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 33,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 34,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 35,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 36,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 37,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 38,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 39,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 40,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 41,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 42,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 43,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 44,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 45,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 46,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 47,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 48,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 49,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 50,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 51,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 52,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 53,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 54,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 55,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 56,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 57,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 58,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 59,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 60,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 61,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 62,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 63,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 64,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 65,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 66,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 67,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 68,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 69,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 70,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 71,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 72,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 73,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 74,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 75,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 76,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 77,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 78,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 79,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 80,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 81,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 82,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 83,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 84,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 85,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 86,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 87,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 88,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 89,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 90,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 91,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 92,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 93,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 94,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 95,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 96,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 97,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 98,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 99,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 100,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 101,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 102,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 103,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 104,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 105,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 106,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 107,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 108,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 109,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 110,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 111,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 112,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 113,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 114,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 115,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 116,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 117,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 118,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 119,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 120,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 121,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 122,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 123,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 124,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 125,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 126,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 127,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 128,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 129,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 130,
# ...
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8152,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8153,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8154,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8155,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8156,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8157,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8158,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8159,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8160,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8161,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8162,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8163,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8164,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8165,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8166,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8167,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8168,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8169,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8170,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8171,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8172,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8173,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8174,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8175,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8176,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8177,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8178,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8179,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8180,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8181,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8182,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8183,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8184,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8185,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8186,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8187,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8188,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8189,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8190,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8191,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8192,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       },
#       {
#         "code": "invalid_request_body",
#         "line": 8193,
#         "message": "`body.model` must be one of [llama-3.1-8b-instant llama-3.3-70b-versatile deepseek-r1-distill-llama-70b mistral-saba-24b meta-llama/llama-4-scout-17b-16e-instruct meta-llama/llama-4-maverick-17b-128e-instruct meta-llama/llama-guard-4-12b]",
#         "param": "body.model"
#       }
#     ],
#     "object": "list"
#   },
#   "expired_at": null,
#   "expires_at": 1749718845,
#   "failed_at": 1749632448,
#   "finalizing_at": null,
#   "in_progress_at": null,
#   "metadata": null,
#   "output_file_id": null,
#   "request_counts": {
#     "completed": 0,
#     "failed": 0,
#     "total": 0
#   }
# }

# %%
response = client.files.content("file_01jxdqgdtdf4htgbahhss4645s")

# %%
response2 = client.files.content("file_01jxdspk4xe4br8mewhpcvqv30")

# %%
output_path = "../data/final_test/combined_llama_part_02_output.jsonl"
with open(output_path, "w", encoding="utf-8") as f:
    f.write(response2)
    
print(f"Batch file saved to {output_path}")
print(f"File size: {len(response2)} characters")
# Out:
# Batch file saved to ../data/final_test/combined_llama_part_02_output.jsonl
# File size: 14106828 characters

# %%
response[0:1000]
# Out:
# '{"id":"batch_req_out_01jxdq1bz5fn58qhknqtqrh3fp","custom_id":"request_9044","response":{"status_code":200,"request_id":"req_01jxdq1ap0exqvj09masr6xsp1","body":{"id":"chatcmpl-9c626f88-9adb-422f-b459-a3b670ea67d3","object":"chat.completion","created":1749585800,"model":"llama-3.3-70b-versatile","choices":[{"index":0,"message":{"role":"assistant","content":"{\\"para_id\\": \\"ewhc_admin_2003_1321#para_18\\", \\"if_law_applied\\": false, \\"application_of_law_phrases\\": [], \\"reason\\": \\"This paragraph discusses a legal principle and cites a previous case (Hellewell v Chief Constable of Derbyshire) but does not apply the law to the specific facts of the current case. It appears to be setting out background legal information and precedent rather than applying the law to the case at hand.\\"}"},"logprobs":null,"finish_reason":"stop"}],"usage":{"queue_time":0.22037715000000002,"prompt_tokens":2365,"prompt_time":0.656967897,"completion_tokens":103,"completion_time":0.444976689,"total_tokens":2468,"to'

# %%
output_path = "../data/final_test/combined_llama_part_01_output.jsonl"
with open(output_path, "w", encoding="utf-8") as f:
    f.write(response)
    
print(f"Batch file saved to {output_path}")
print(f"File size: {len(response)} characters")
# Out:
# Batch file saved to ../data/final_test/combined_llama_part_01_output.jsonl
# File size: 13909747 characters

# %%
# Combine two JSONL files into one
input_file1 = "../data/final_test/combined_llama_part_01_output.jsonl"
input_file2 = "../data/final_test/combined_llama_part_02_output.jsonl"
output_file = "../data/final_test/combined_llama_output.jsonl"

# Read and combine the files
with open(output_file, 'w', encoding='utf-8') as outfile:
    # Process first file
    with open(input_file1, 'r', encoding='utf-8') as infile1:
        for line in infile1:
            outfile.write(line)
    
    # Process second file
    with open(input_file2, 'r', encoding='utf-8') as infile2:
        for line in infile2:
            outfile.write(line)

print(f"Combined file saved to: {output_file}")

# Verify the number of lines in each file
with open(input_file1, 'r', encoding='utf-8') as f1:
    lines1 = sum(1 for _ in f1)
with open(input_file2, 'r', encoding='utf-8') as f2:
    lines2 = sum(1 for _ in f2)
with open(output_file, 'r', encoding='utf-8') as f3:
    lines3 = sum(1 for _ in f3)

print(f"Number of lines in first file: {lines1}")
print(f"Number of lines in second file: {lines2}")
print(f"Number of lines in combined file: {lines3}")
# Out:
# Combined file saved to: ../data/final_test/combined_llama_output.jsonl
# Number of lines in first file: 12289
# Number of lines in second file: 12289
# Number of lines in combined file: 24578

# %%
import extract_data_from_jsonl

# %%
combined_csv_path = '../data/final_test/combined_sampled_caselaws.csv'
output_jsonl_path = '../data/final_test/combined_llama_output.jsonl'
output_csv_path = '../data/final_test/combined_llama_output.csv'
extract_data_from_jsonl.merge_combined_csv_and_output_jsonl(combined_csv_path, output_jsonl_path, output_csv_path)
# Out:
# Merged CSV saved to: ../data/final_test/combined_llama_output.csv
#                                             case_uri  \
# 0  https://caselaw.nationalarchives.gov.uk/ewhc/c...
# 1  https://caselaw.nationalarchives.gov.uk/ewhc/c...
# 2  https://caselaw.nationalarchives.gov.uk/ewhc/c...
# 3  https://caselaw.nationalarchives.gov.uk/ewhc/c...
# 4  https://caselaw.nationalarchives.gov.uk/ewhc/c...
#
#                     para_id  \
# 0  ewhc_ch_2009_1229#para_1
# 1  ewhc_ch_2009_1229#para_2
# 2  ewhc_ch_2009_1229#para_3
# 3  ewhc_ch_2009_1229#para_4
# 4  ewhc_ch_2009_1229#para_5
#
#                                           paragraphs references  \
# 0  1. The Revenue’s appeal to the High Court was ...         []
# 1  2. I circulated my judgment to the parties in ...         []
# 2  3. On 16 January BLP forwarded to my clerk a w...         []
# 3  4. The reasons given by Dr Banerjee for reques...         []
# 4  5. Dr Banerjee went on to say that she oversee...         []
#
#   if_law_applied application_of_law_phrases  \
# 0          False                         []
# 1          False                         []
# 2          False                         []
# 3          False                         []
# 4          False                         []
#
#                                               reason
# 0  This paragraph provides background procedural ...
# 1  This paragraph contains background procedural ...
# 2  This paragraph discusses procedural matters an...
# 3  This paragraph presents the applicant's reason...
# 4  This paragraph presents Dr Banerjee's personal...
# Index(['case_uri', 'para_id', 'paragraphs', 'references', 'if_law_applied',
#        'application_of_law_phrases', 'reason'],
#       dtype='object')

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('../data/final_test/combined_llama_output.csv')

# Count how many rows have True in if_law_applied column
true_count = df['if_law_applied'].sum()
total_rows = len(df)

print(f"Number of rows with law application: {true_count}")
print(f"Total number of rows: {total_rows}")
print(f"Percentage of rows with law application: {(true_count/total_rows)*100:.2f}%")
# Out:
# Number of rows with law application: 9262
# Total number of rows: 24960
# Percentage of rows with law application: 37.11%

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-search-preview",
    messages=[
        {
            "role": "user",
            "content": """Given the pargraph_text from a case_law and text excerpt from this paragraph where law is applied is given . Also the reason of why this text is classified as having the text where law is applied is also given. Your task is to find the relevant legislation acts and provision from https://www.justice.gov.uk/ and https://www.legislation.gov.uk/ and also the give me the exact text from the reference which matches or applied here. Your response should be in the list of json [{'case_law_excerpt':'legislation_excerpt':'url_of_legislation_act_section': ,'confidence':}]{"pargraph_text" = "During the course of the hearing of Astex’s application, the form in which the claim for privilege was made by AZ was described as “conventional”. I accept that the claim for legal advice privilege is described adequately. However, although it may have been conventional at one time to state that other documents are “by their nature privileged”, such a statement has no place in modern litigation, let alone litigation of very real complexity. It is clearly unhelpful, without describing the documents said to be privileged, to say that ‘their nature’ explains why they are privileged because the recipient of the list of documents has no way of knowing which documents, or classes of documents, are being referred to."
"law_of_Appliaction_text_exceprts" =['although it may have been conventional at one time to state that other documents are “by their nature privileged”, such a statement has no place in modern litigation']
"reasoning" = "The judge applies legal principles related to claims of legal advice privilege, specifically criticizing the inadequacy of the claimant's approach to asserting privilege in a modern litigation context, thereby implying the application of rules or protocols governing the assertion of privilege in complex cases."
}

Rules:
- The given text should strictly be from the given references. You should not made anything from your own side 
-The caselaw text should strictly from the text I gave you

""",
        }
    ],
)

print(completion.choices[0].message.content)
# Out:
# Based on the provided case law excerpt and the principles of legal advice privilege, the following relevant legislation and provisions have been identified:
#
#
# ```json
# [
#   {
#     "case_law_excerpt": "although it may have been conventional at one time to state that other documents are “by their nature privileged”, such a statement has no place in modern litigation",
#     "legislation_excerpt": "Legal advice privilege covers confidential communications passing between lawyer and client for the purpose of seeking and furnishing legal advice, whether or not in the context of litigation.",
#     "url_of_legislation_act_section": "https://www.dlapiper.com/en/insights/publications/2020/03/maintaining-the-privilege-procedure-and-practice-privilege",
#     "confidence": 0.9
#   },
#   {
#     "case_law_excerpt": "although it may have been conventional at one time to state that other documents are “by their nature privileged”, such a statement has no place in modern litigation",
#     "legislation_excerpt": "Legal advice privilege protects confidential communications between lawyers and their clients for the purposes of giving or obtaining legal advice.",
#     "url_of_legislation_act_section": "https://en.wikipedia.org/wiki/Legal_professional_privilege_in_England_and_Wales",
#     "confidence": 0.85
#   },
#   {
#     "case_law_excerpt": "although it may have been conventional at one time to state that other documents are “by their nature privileged”, such a statement has no place in modern litigation",
#     "legislation_excerpt": "Legal advice privilege covers confidential communications between a lawyer and their client for the purpose of obtaining or giving legal advice.",
#     "url_of_legislation_act_section": "https://www.gov.uk/hmrc-internal-manuals/compliance-handbook/ch22244",
#     "confidence": 0.8
#   }
# ]
# ```
#
#
# These excerpts highlight the necessity for clear and specific assertions of legal advice privilege in modern litigation, moving away from generalized claims that documents are privileged by their nature.

# %%
import anthropic
import os
api_key=os.environ.get("ANTHROPIC_API_KEY")
print(api_key)
client = anthropic.Anthropic(api_key=api_key)

response = client.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=8192,
    messages=[
        {
            "role": "user",
               "content": """Given the pargraph_text from a case_law and text excerpt from this paragraph where law is applied is given . Also the reason of why this text is classified as having the text where law is applied is also given. Your task is to find the relevant legislation acts and provision from allowed domains and also the give me the exact text from the reference which matches or applied here. Your response should be in the list of json [{'case_law_excerpt':'legislation_excerpt':'url_of_legislation_act_section': ,'confidence':}]{"pargraph_text" = "During the course of the hearing of Astex’s application, the form in which the claim for privilege was made by AZ was described as “conventional”. I accept that the claim for legal advice privilege is described adequately. However, although it may have been conventional at one time to state that other documents are “by their nature privileged”, such a statement has no place in modern litigation, let alone litigation of very real complexity. It is clearly unhelpful, without describing the documents said to be privileged, to say that ‘their nature’ explains why they are privileged because the recipient of the list of documents has no way of knowing which documents, or classes of documents, are being referred to."
"law_of_Appliaction_text_exceprts" =['although it may have been conventional at one time to state that other documents are “by their nature privileged”, such a statement has no place in modern litigation']
"reasoning" = "The judge applies legal principles related to claims of legal advice privilege, specifically criticizing the inadequacy of the claimant's approach to asserting privilege in a modern litigation context, thereby implying the application of rules or protocols governing the assertion of privilege in complex cases."
}

Rules:
- The given text should strictly be from the given references. You should not made anything from your own side 
-The caselaw text should strictly from the text I gave you

"""
        }
    ],
    tools=[{
        "type": "web_search_20250305",
        "name": "web_search",
        "max_uses": 5,
        "allowed_domains": ["legislation.gov.uk/uksi/1998/3132"]
    }]
)
print(response)
# Out:
# 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
# Message(id='msg_01Frhxa44GLDwSbGCRpfcMj4', content=[ServerToolUseBlock(id='srvtoolu_01YDV8jFhp4o3TyEFDVjQMcE', input={'query': 'legal advice privilege modern litigation UK law'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(content=[WebSearchResultBlock(encrypted_content='...', page_age=None, title='The Civil Procedure Rules 1998', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/part/22/made?view=plain'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='https://www.legislation.gov.uk/uksi/1998/3132/rule/6.25/ ...', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/rule/6.25/data.akn'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Legislation', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/rule/27.14/2005-03-14/data.xht'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='https://www.legislation.gov.uk/uksi/1998/3132/rule/76.25/ ...', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/rule/76.25/2008-12-12/data.akn'), WebSearchResultBlock(encrypted_content='', page_age=None, title='https://www.legislation.gov.uk/uksi/1998/3132/rule/52.20/ ...', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/rule/52.20/2016-10-03/data.akn'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='The Civil Procedure Rules 1998 No. 3132 (L. 17)', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/1999-04-26/data.xht?view=snippet&wrap=true'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='The Civil Procedure Rules 1998', type='web_search_result', url='https://legislation.gov.uk/uksi/1998/3132/article/27.14/made'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='https://www.legislation.gov.uk/uksi/1998/3132/rule/31.19/ ...', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/rule/31.19/2020-08-23/data.akn')], tool_use_id='srvtoolu_01YDV8jFhp4o3TyEFDVjQMcE', type='web_search_tool_result'), ServerToolUseBlock(id='srvtoolu_01YP1D9q6AU9zZrGW29FhS8e', input={'query': 'Civil Procedure Rules disclosure privilege modern litigation'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(content=[WebSearchResultBlock(encrypted_content='...', page_age=None, title='The Civil Procedure Rules 1998', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/part/31/made'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='The Civil Procedure Rules 1998 No. 3132 (L. 17)', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/part/31/2009-04-06/data.xht?view=snippet&wrap=true'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Legislation', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/rule/31.17/2021-11-12/data.akn')], tool_use_id='srvtoolu_01YP1D9q6AU9zZrGW29FhS8e', type='web_search_tool_result'), ServerToolUseBlock(id='srvtoolu_01SYFCKNWMCFozWiZ1NSGiJf', input={'query': 'CPR 31.19 privilege disclosure statement'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(content=[WebSearchResultBlock(encrypted_content='...', page_age=None, title='PART 31 - The Civil Procedure Rules 1998', type='web_search_result', url='https://www.legislation.gov.uk/uksi/1998/3132/part/31/made'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='The Civil Procedure Rules 1998 No. 3132 (L. 17)', type='web_search_result', url='https://www.legislation.gov.uk/ ...

# %%
for i in range(len(response.content)):
    print(response.content[i].text)
# Out:
# I'll search for relevant legislation regarding legal advice privilege and document disclosure requirements in litigation.
# None
# None
# None
# None
# None
# None
# Based on my search of the UK legislation websites, I can now provide the relevant legislation that applies to the case law excerpt regarding privilege claims in disclosure. Here is the analysis in the requested JSON format:
#
# ```json
# [
#   {
#     "case_law_excerpt": "although it may have been conventional at one time to state that other documents are 'by their nature privileged', such a statement has no place in modern litigation",
#     "legislation_excerpt": "A person who wishes to claim that he has a right or a duty to withhold inspection of a document, or part of a document, must state in writing—(a) that he has such a right or duty; and (b) the grounds on which he claims that right or duty",
#     "url_of_legislation_act_section": "https://www.legislation.gov.uk/uksi/1998/3132/part/31/made",
#     "confidence": 0.95
#   },
#   {
#     "case_law_excerpt": "although it may have been conventional at one time to state that other documents are 'by their nature privileged', such a statement has no place in modern litigation",
#     "legislation_excerpt": "If the disclosing party wishes to claim that he has a right or duty to withhold a document, or part of a document, in his list of documents from inspection (see rule 31.19(3)), he must state in writing: (a) that he has such a right or duty; and (b) the grounds on which he claims that right or duty",
#     "url_of_legislation_act_section": "https://www.justice.gov.uk/courts/procedure-rules/civil/rules/part31/pd_part31a",
#     "confidence": 0.95
#   },
#   {
#     "case_law_excerpt": "although it may have been conventional at one time to state that other documents are 'by their nature privileged', such a statement has no place in modern litigation",
#     "legislation_excerpt": "The list must identify the documents in a convenient order and manner and as concisely as possible",
#     "url_of_legislation_act_section": "https://www.legislation.gov.uk/uksi/1998/3132/part/31/made",
#     "confidence": 0.85
#   },
#   {
#     "case_law_excerpt": "although it may have been conventional at one time to state that other documents are 'by their nature privileged', such a statement has no place in modern litigation",
#     "legislation_excerpt": "The statement referred to in paragraph 4.5 above should normally be included in the disclosure statement and must indicate the document, or part of a document, to which the claim relates",
#     "url_of_legislation_act_section": "https://www.justice.gov.uk/courts/procedure-rules/civil/rules/part31/pd_part31a",
#     "confidence": 0.90
#   }
# ]
# ```
#
# The judge's criticism that stating documents are "by their nature privileged" has no place in modern litigation directly relates to
# CPR Part 31.19(3) and Practice Direction 31A paragraph 4.5, which require parties claiming privilege to specifically state in writing both that they have a right or duty to withhold inspection and the grounds on which they claim that right or duty
# . The rules mandate
# that the party must indicate the specific document or part of a document to which the claim relates
# , rather than making vague assertions about documents being privileged "by their nature."

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-search-preview",
    messages=[
        {
            "role": "user",
            "content": "What was a positive news story from today?",
        }
    ],
)

print(completion.choices[0].message.content)
# Out:
# As of June 24, 2025, here are some recent positive news stories:
#
# **Environmental Progress**
#
# - **U.S. Introduces Limits on 'Forever Chemicals' in Drinking Water**: In April 2024, the Environmental Protection Agency (EPA) set its first-ever national legally enforceable limits on per- and polyfluoroalkyl substances (PFAS) in drinking water. This regulation aims to reduce PFAS exposure for approximately 100 million people by 2029. ([homeplanet.grove.co](https://homeplanet.grove.co/blog-posts/positive-environmental-news-stories-that-give-us-hope-in-2025?utm_source=openai))
#
# - **EU's Nature Restoration Law**: The European Union enacted the Nature Restoration Law, a comprehensive initiative to restore damaged ecosystems and boost biodiversity. The law targets the restoration of 20% of the EU's land and sea areas by 2030 and all degraded ecosystems by 2050. ([homeplanet.grove.co](https://homeplanet.grove.co/blog-posts/positive-environmental-news-stories-that-give-us-hope-in-2025?utm_source=openai))
#
# **Conservation Efforts**
#
# - **Sea Turtle Nest Record Broken in Florida**: Anna Maria Island, off Florida's Gulf Coast, reported a record 546 sea turtle nests, surpassing a 42-year-old record. Conservation efforts also led to the return of the least tern, a threatened bird species, for the first time in 15 years. ([homeplanet.grove.co](https://homeplanet.grove.co/blog-posts/positive-environmental-news-stories-that-give-us-hope-in-2025?utm_source=openai))
#
# - **Leadbeater’s Possum Rediscovered in New South Wales**: A critically endangered Leadbeater’s possum, previously thought extinct in New South Wales, was found in Kosciuszko National Park, over 250 km from the nearest known population in Victoria. ([conservationoptimism.org](https://conservationoptimism.org/7-stories-of-optimism-this-week-26-05-25-02-06-25/?utm_source=openai))
#
# **Community Initiatives**
#
# - **Beekeeper Inspires Urban Youth in Leeds**: Kate Turner, a beekeeper from Leeds, established Bee Inspired Eco Education to educate urban schoolchildren about the natural world, fostering a connection with nature among young people. ([globalgoodnews.com](https://www.globalgoodnews.com/?utm_source=openai))
#
# **Scientific Advancements**
#
# - **NASA's Hubble Captures Detailed Image of Dwarf Galaxy**: The Hubble Space Telescope captured a stunning image of the Large Magellanic Cloud, showcasing a dazzling swirl of gas and dust clouds in the Milky Way's largest satellite galaxy. ([globalgoodnews.com](https://www.globalgoodnews.com/?utm_source=openai))
#
# These stories highlight ongoing efforts and achievements in environmental conservation, community engagement, and scientific exploration.
